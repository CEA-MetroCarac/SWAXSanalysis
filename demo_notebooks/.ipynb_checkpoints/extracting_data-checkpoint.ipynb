# %%
import sys
# !{sys.executable} -m pip uninstall smi-analysis --yes
# !{sys.executable} -m pip install git+https://github.com/gfreychet/smi-analysis.git
# Out:
# Found existing installation: smi-analysis 0.1.0.post70+g87cab36
# Uninstalling smi-analysis-0.1.0.post70+g87cab36:
#   Successfully uninstalled smi-analysis-0.1.0.post70+g87cab36
# Collecting git+https://github.com/gfreychet/smi-analysis.git
#   Cloning https://github.com/gfreychet/smi-analysis.git to c:\users\at280565\appdata\local\temp\pip-req-build-89jkyy4a
#   Resolved https://github.com/gfreychet/smi-analysis.git to commit 87cab36948499bc82bfef49101843bfc13014bb7
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: h5py in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from smi-analysis==0.1.0.post70+g87cab36) (3.12.1)
# Requirement already satisfied: numpy in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from smi-analysis==0.1.0.post70+g87cab36) (1.24.3)
# Requirement already satisfied: pyFAI in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from smi-analysis==0.1.0.post70+g87cab36) (2023.5.0)
# Requirement already satisfied: pygix>=2022.11.14 in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from smi-analysis==0.1.0.post70+g87cab36) (2022.11.14)
# Requirement already satisfied: scipy in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from smi-analysis==0.1.0.post70+g87cab36) (1.10.1)
# Requirement already satisfied: xarray in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from smi-analysis==0.1.0.post70+g87cab36) (2023.5.0)
# Requirement already satisfied: silx in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from pyFAI->smi-analysis==0.1.0.post70+g87cab36) (1.1.2)
# Requirement already satisfied: fabio in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from pyFAI->smi-analysis==0.1.0.post70+g87cab36) (2023.4.1)
# Requirement already satisfied: numexpr in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from pyFAI->smi-analysis==0.1.0.post70+g87cab36) (2.8.4)
# Requirement already satisfied: matplotlib in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from pyFAI->smi-analysis==0.1.0.post70+g87cab36) (3.7.1)
# Requirement already satisfied: pandas>=1.4 in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from xarray->smi-analysis==0.1.0.post70+g87cab36) (1.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from xarray->smi-analysis==0.1.0.post70+g87cab36) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from pandas>=1.4->xarray->smi-analysis==0.1.0.post70+g87cab36) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from pandas>=1.4->xarray->smi-analysis==0.1.0.post70+g87cab36) (2023.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from matplotlib->pyFAI->smi-analysis==0.1.0.post70+g87cab36) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from matplotlib->pyFAI->smi-analysis==0.1.0.post70+g87cab36) (4.40.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from matplotlib->pyFAI->smi-analysis==0.1.0.post70+g87cab36) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from matplotlib->pyFAI->smi-analysis==0.1.0.post70+g87cab36) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from matplotlib->pyFAI->smi-analysis==0.1.0.post70+g87cab36) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from matplotlib->pyFAI->smi-analysis==0.1.0.post70+g87cab36) (3.0.9)
# Requirement already satisfied: setuptools in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from silx->pyFAI->smi-analysis==0.1.0.post70+g87cab36) (67.8.0)
# Requirement already satisfied: six>=1.5 in c:\dev\sw\envs3\env_metrocarac\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.4->xarray->smi-analysis==0.1.0.post70+g87cab36) (1.16.0)
# Installing collected packages: smi-analysis
#   Running setup.py install for smi-analysis: started
#   Running setup.py install for smi-analysis: finished with status 'done'
# Successfully installed smi-analysis-0.1.0.post70+g87cab36
#   Running command git clone --filter=blob:none --quiet https://github.com/gfreychet/smi-analysis.git 'C:\Users\AT280565\AppData\Local\Temp\pip-req-build-89jkyy4a'
#   DEPRECATION: smi-analysis is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: C:\dev\sw\envs3\env_metrocarac\Scripts\python.exe -m pip install --upgrade pip

# %% [markdown]
# # Visualize the structure of the .h5 file with NeXus standard
#
# The first step is to visualize the structure of the file and all the data / metadata it contains.
# There are three types of element :
#
#     - Groups (red) : you can view them as a directory, it can contain other groups or dataset and has attributes
#     - Datasets (blue) : you can view them as a file, it can have attributes
#     - Attributes (green) : you can view them as properties. They don't contain anything and they're additional info
#
# To visualize t you just have to change the absolute path of the .h5 file you want to use. Don't forget to put two "\" if you use them, if you use "/" no modification is necessary. It is the only variable you need to change here

# %%
# %matplotlib notebook

import os
import h5py
from colorama import Fore, Style
import matplotlib.pyplot as plt
import numpy as np
from smi_analysis import SMI_beamline


file_path = 'C:\\Users\\AT280565\\PycharmProjects\\EdfToHdf5\\edf2NxSAS\\treated data\\instrument - Xeuss\\config - 2024-12-19T15-00\\sample - Guillaume\\experiment - SAXS\\format - NXsas\\sample_sow7-143_SAXS_2025-01-03T09-52-25.h5'

#file_path = 'C:\\Users\\AT280565\\PycharmProjects\\EdfToHdf5\\data\\NeXus_files\\sample11_waxs_2024-11-05T17-03-21.h5'
#file_path = "C:\\Users\\AT280565\\PycharmProjects\\EdfToHdf5\\data\\NeXus_files\\sample12_waxs_2024-11-05T17-21-11.h5"

#file_path = "C:\\Users\\AT280565\\PycharmProjects\\EdfToHdf5\\data\\NeXus_files\\sample_sow7-143_saxs_2024-11-06T08-30-30.h5"

# directory_path = 'C:\\Users\\AT280565\\PycharmProjects\\EdfToHdf5\\NeXusFiles\\'
# file_name = "sample_sow7-143_saxs_2024-11-04T14-26-18.h5"



def explore_file(group, level=0):
    indent = "|  " * level
    for key in group.keys():
        item = group[key]
        if isinstance(item, h5py.Group):
            print(f"{indent}{Fore.RED}Group : {key}{Style.RESET_ALL}")
            explore_file(item, level + 1)
        elif isinstance(item, h5py.Dataset):
            print(f"{indent}{Fore.CYAN}Dataset : {key}{Style.RESET_ALL}")
            if item.attrs:
                print(f"{indent}  {Fore.GREEN}Attributes : {key}{Style.RESET_ALL}")
                for key_attribute, item_attribute in item.attrs.items():
                    print(f"{indent}    - {key_attribute} : {item_attribute}")
            
file = h5py.File(file_path, 'r')
explore_file(file)
file.close()
# Out:
# WARNING:silx.opencl.common:Unable to import pyOpenCl. Please install it from: https://pypi.org/project/pyopencl
# Group : ENTRY
# |  Group : DATA
# |  |  Dataset : I
# |  |    Attributes : I
# |  |      - EX_required : True
# |  |      - docstring : Array of I measured.
# |  |      - scaling_factor : I_scaling
# |  |      - type : NX_NUMBER
# |  |      - uncertainties : Idev
# |  |      - units : arbitrary
# |  |  Dataset : Idev
# |  |    Attributes : Idev
# |  |      - EX_required : True
# |  |      - docstring : Array of I's uncertainties.
# |  |      - type : NX_NUMBER
# |  |      - units : arbitrary
# |  |  Dataset : R
# |  |    Attributes : R
# |  |      - EX_required : True
# |  |      - docstring : Array of R (positions), can be an array of 3D vector or an array of scalar representing |R|
# |  |      - resolutions : dRl, dRw
# |  |      - resolutions_description : Gaussian
# |  |      - type : NX_NUMBER
# |  |      - uncertainties : Rdev
# |  |      - units : nm
# |  |  Dataset : Rdev
# |  |    Attributes : Rdev
# |  |      - EX_required : False
# |  |      - docstring : Array of R's uncertainties'
# |  |      - type : NX_NUMBER
# |  |      - units : nm
# |  |  Dataset : Rmean
# |  |    Attributes : Rmean
# |  |      - EX_required : False
# |  |      - docstring : Mean value of R at that point, usefull when binning
# |  |      - type : NX_NUMBER
# |  |      - units : nm
# |  |  Dataset : dRl
# |  |    Attributes : dRl
# |  |      - EX_required : False
# |  |      - docstring : Array of R's horizontal resolution'
# |  |      - type : NX_NUMBER
# |  |      - units : nm
# |  |  Dataset : dRw
# |  |    Attributes : dRw
# |  |      - EX_required : False
# |  |      - docstring : Array of R's vertical resolution'
# |  |      - type : NX_NUMBER
# |  |      - units : nm
# |  |  Dataset : mask
# |  |    Attributes : mask
# |  |      - EX_required : True
# |  |      - docstring : Array describing the mask used
# |  |      - type : NX_NUMBER
# |  Group : INSTRUMENT
# |  |  Group : APERTURE
# |  |  |  Dataset : shape
# |  |  |    Attributes : shape
# |  |  |      - EX_required : True
# |  |  |      - docstring : Shape of the instrument's aperture
# |  |  |      - type : NX_CHAR
# |  |  |  Dataset : x_gap
# |  |  |    Attributes : x_gap
# |  |  |      - EX_required : False
# |  |  |      - docstring : Horizontal width of the slit
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : arbitrary
# |  |  |  Dataset : y_gap
# |  |  |    Attributes : y_gap
# |  |  |      - EX_required : False
# |  |  |      - docstring : Vertical width of the slit
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : arbitrary
# |  |  Group : COLLIMATOR
# |  |  |  Dataset : distance
# |  |  |    Attributes : distance
# |  |  |      - EX_required : False
# |  |  |      - docstring : collimator-sample distance
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : arbitrary
# |  |  |  Dataset : length
# |  |  |    Attributes : length
# |  |  |      - EX_required : False
# |  |  |      - docstring : Length of collimation
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : arbitrary
# |  |  Group : DETECTOR
# |  |  |  Dataset : SDD
# |  |  |    Attributes : SDD
# |  |  |      - EX_required : True
# |  |  |      - docstring : sample-detector distance
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : arbitrary
# |  |  |  Dataset : beam_center_x
# |  |  |    Attributes : beam_center_x
# |  |  |      - EX_required : True
# |  |  |      - docstring : Horizontal position of the beam center (where it would hit without the sample)
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : arbitrary
# |  |  |  Dataset : beam_center_y
# |  |  |    Attributes : beam_center_y
# |  |  |      - EX_required : True
# |  |  |      - docstring : Vertical position of the beam center (where it would hit without the sample)
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : arbitrary
# |  |  |  Dataset : name
# |  |  |    Attributes : name
# |  |  |      - EX_required : True
# |  |  |      - docstring : name of the detector
# |  |  |      - type : NX_CHAR
# |  |  |  Dataset : pitch
# |  |  |    Attributes : pitch
# |  |  |      - EX_required : True
# |  |  |      - docstring : Rotation of the detector on the horizontal axis
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : rad
# |  |  |  Dataset : roll
# |  |  |    Attributes : roll
# |  |  |      - EX_required : True
# |  |  |      - docstring : Rotation of the detector on the axis of the source
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : rad
# |  |  |  Dataset : slit_length
# |  |  |    Attributes : slit_length
# |  |  |      - EX_required : False
# |  |  |      - docstring : length of the detector's slit
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : nm
# |  |  |  Dataset : x_pixel_size
# |  |  |    Attributes : x_pixel_size
# |  |  |      - EX_required : True
# |  |  |      - docstring : Horizontal size of the detector's pixel
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : arbitrary
# |  |  |  Dataset : x_position
# |  |  |    Attributes : x_position
# |  |  |      - EX_required : True
# |  |  |      - docstring : Horizontal position of the detector
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : arbitrary
# |  |  |  Dataset : y_pixel_size
# |  |  |    Attributes : y_pixel_size
# |  |  |      - EX_required : True
# |  |  |      - docstring : Vertical size of the detector's pixel
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : arbitrary
# |  |  |  Dataset : y_position
# |  |  |    Attributes : y_position
# |  |  |      - EX_required : True
# |  |  |      - docstring : Vertical position of the detector
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : arbitrary
# |  |  |  Dataset : yaw
# |  |  |    Attributes : yaw
# |  |  |      - EX_required : True
# |  |  |      - docstring : Rotation of the detector on the vertical axis
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : rad
# |  |  Group : SOURCE
# |  |  |  Dataset : beam_size_x
# |  |  |    Attributes : beam_size_x
# |  |  |      - EX_required : False
# |  |  |      - docstring : Horizontal size of the beam
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : arbitrary
# |  |  |  Dataset : beam_size_y
# |  |  |    Attributes : beam_size_y
# |  |  |      - EX_required : False
# |  |  |      - docstring : Horizontal size of the beam
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : arbitrary
# |  |  |  Dataset : incident_wavelength
# |  |  |    Attributes : incident_wavelength
# |  |  |      - EX_required : True
# |  |  |      - docstring : Wavelength of the incident radiation
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : nm
# |  |  |  Dataset : probe
# |  |  |    Attributes : probe
# |  |  |      - EX_required : False
# |  |  |      - docstring : type of radiation used
# |  |  |      - type : NX_CHAR
# |  |  |  Dataset : type
# |  |  |    Attributes : type
# |  |  |      - EX_required : False
# |  |  |      - docstring : type of source used
# |  |  |      - type : NX_CHAR
# |  |  |  Dataset : wavelength_max
# |  |  |    Attributes : wavelength_max
# |  |  |      - EX_required : False
# |  |  |      - docstring : Maximum wavelength if a range is specified
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : nm
# |  |  |  Dataset : wavelength_min
# |  |  |    Attributes : wavelength_min
# |  |  |      - EX_required : False
# |  |  |      - docstring : Minimum wavelength if a range is specified
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : nm
# |  |  |  Dataset : wavelength_spread
# |  |  |    Attributes : wavelength_spread
# |  |  |      - EX_required : False
# |  |  |      - docstring : The FWHM of the wavelength range
# |  |  |      - type : NX_NUMBER
# |  |  |      - units : nm
# |  Group : SAMPLE
# |  |  Dataset : pitch
# |  |    Attributes : pitch
# |  |      - EX_required : True
# |  |      - docstring : Rotation of the sample on the horizontal axis
# |  |      - type : NX_NUMBER
# |  |      - units : rad
# |  |  Dataset : roll
# |  |    Attributes : roll
# |  |      - EX_required : True
# |  |      - docstring : Rotation of the sample on the axis of the source
# |  |      - type : NX_NUMBER
# |  |      - units : rad
# |  |  Dataset : temperature
# |  |    Attributes : temperature
# |  |      - EX_required : False
# |  |      - docstring : Temperature of the sample
# |  |      - type : NX_NUMBER
# |  |      - units : arbitrary
# |  |  Dataset : thickness
# |  |    Attributes : thickness
# |  |      - EX_required : False
# |  |      - docstring : Thickness of the sample
# |  |      - type : NX_NUMBER
# |  |      - units : arbitrary
# |  |  Dataset : transmission
# |  |    Attributes : transmission
# |  |      - EX_required : False
# |  |      - docstring : Transmission of the sample (no Unit)
# |  |      - type : NX_NUMBER
# |  |  Dataset : x_position
# |  |    Attributes : x_position
# |  |      - EX_required : True
# |  |      - docstring : Horizontal position of the sample
# |  |      - type : NX_NUMBER
# |  |      - units : arbitrary
# |  |  Dataset : y_position
# |  |    Attributes : y_position
# |  |      - EX_required : True
# |  |      - docstring : Vertical position of the sample
# |  |      - type : NX_NUMBER
# |  |      - units : arbitrary
# |  |  Dataset : yaw
# |  |    Attributes : yaw
# |  |      - EX_required : True
# |  |      - docstring : Rotation of the sample on the vertical axis
# |  |      - type : NX_NUMBER
# |  |      - units : rad
# |  Dataset : definition
# |    Attributes : definition
# |      - EX_required : True
# |      - docstring : NeXus schema used for this file
# |      - type : NX_CHAR
# |  Dataset : run
# |    Attributes : run
# |      - EX_required : True
# |      - docstring : Identification of this experiment
# |      - name :
# |      - type : NX_CHAR
# |  Dataset : title
# |    Attributes : title
# |      - EX_required : True
# |      - docstring : Title of this file, should be something meaningfull
# |      - type : NX_CHAR

# %% [markdown]
# # Extract a dataset into a python variable
#
# If you want to extract a dataset and one of it's attribute (for example the wavelength and it's unit) you simply have to follow the folowing model :

# %%
# Open your file
file = h5py.File(file_path, 'r')

# Extract the dataset by specifying its path and its attribute by using the method attrs
dataset_wavelength = file["ENTRY/INSTRUMENT/SOURCE/incident_wavelength"]
attributes_wavelength = dataset_wavelength.attrs

# Extract the value by copying its content into another variable
float_wavelength = dataset_wavelength[()]
str_unit = attributes_wavelength["units"]
print(f"Wavelength : {float_wavelength} {str_unit}")

file.close()
# Out:
# Wavelength : 0.1541891 nm

# %% [markdown]
# # Plot experimental data
#
# To plot experimental data you have to extract the data set with the method that was just described. But since this data is probably an array of point, you have to put ":" instead of "()" which is for scalars.
#
# After that you only have to plot the data using matplotlib.pyplot

# %%
# Open your file
file = h5py.File(file_path, 'r')

# Extract the dataset
dataset_raw = file["ENTRY/DATA/I"]

# Extract the array by copying its content into another variable
array_raw = dataset_raw[:]

# Plot using matplotlib
fig, ax = plt.subplots()
plot = ax.imshow(array_raw, vmin=0, vmax=np.percentile(array_raw, 99), cmap="magma")

ax.set_title("Plot of the raw data")
ax.set_xlabel("$p_{x} (pixels)$")
ax.set_ylabel("$p_{y} (pixels)$")

cbar = plt.colorbar(plot, ax=ax)
cbar.set_label("Intensity")

file.close()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Simple processing of the raw data
#
# To start we can do a simple processing of the raw data. For example we can sum the value on a strip of pixel that goes accros the luminous spot.
#
# If you want to change the thickness of the strip you can change the parameters y_min and y_max

# %%
# We copy the strips of interest in new variables
y_min = 800
y_max = 830
array_raw_strip1 = array_raw[y_min:y_max:1, :]

# We sum the value of the pixel of coordinate (x, y_min) to (x, y_max) for all x
list_sum_strip1 = np.sum(array_raw_strip1, axis=0)

# We plot the result
fig, ax = plt.subplots()
plot = ax.plot(list_sum_strip1, color="darkblue")

ax.set_title("Sum of the intensity for the strip of pixel going from\n" \
             f"y={y_min} to y={y_max}")
ax.set_xlabel("$p_{x}$ (Pixels)")
ax.set_ylabel("Sum of intensity")
ax.set_yscale("log")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Extraction of the necessary data from the file
#
# Here we are going to define a function that will extract all values required by the python package smi_analysis.
#
# You don't have to change anything here

# %%
def extract_parameters(file_path):
    dict_parameters = {
        "beam stop": [[0, 0]]
    }
    
    file = h5py.File(file_path, 'r')
    def extract_fromH5(path, type="dataset", attribute_name=None):
        dataset = file[path]
        attributes = dataset.attrs
        if type == "dataset" and np.shape(dataset) == ():
            return dataset[()]
        elif type == "dataset" and np.shape(dataset) != ():
            return dataset[:]
        elif type == "attribute" and attribute_name in attributes.keys():
            return attributes(attribute_name)
        else:
            print(f"error while extracting from {path}")
            return None
        
    # Name of the detector
        if "dectris eiger2 si 1m, s/n e-02-0299" in str(extract_fromH5("ENTRY/INSTRUMENT/DETECTOR/name)).lower():
            dict_parameters["detector"] = "Eiger1M_xeuss"
        elif "dectris eiger2 r 500k, s/n e-01-0326" in str(extract_fromH5("ENTRY/INSTRUMENT/DETECTOR/name")).lower():
            dict_parameters["detector"] = "Eiger500k_xeuss"
    
    # Raw data from the experiment
    raw_data = extract_fromH5("ENTRY/DATA/I")
    dict_parameters["data"] = [raw_data]
    
#     # Geometry of the experiment
#     geometry = extract_fromH5("ENTRY/INSTRUMENT/DETECTOR/geometry")
#     geometry = str(geometry).strip("b").strip("'").title()
#     dict_parameters["geometry"] = str(geometry)
    
    # Center of the beam along the x axis
    beam_center_x = extract_fromH5("ENTRY/INSTRUMENT/DETECTOR/beam_center_x")
    beam_center_y = extract_fromH5("ENTRY/INSTRUMENT/DETECTOR/beam_center_y")
    dict_parameters["beam center"] = [beam_center_x, beam_center_y]
    
    # Sample-detector distance
    sample_detector_distance = extract_fromH5("ENTRY/INSTRUMENT/DETECTOR/SDD")
    dict_parameters["distance"] = sample_detector_distance
    
    # Incident wavelength
    wavelength = extract_fromH5("ENTRY/INSTRUMENT/SOURCE/incident_wavelength")
    dict_parameters["wavelength"] = wavelength * 1e-9
    
    # Incident angle
    alpha = np.deg2rad(0.5)
    dict_parameters["alpha"] = alpha
    
    # Rotations of the detector along the x / y / z axis respectively
    rotation_1 = -extract_fromH5("ENTRY/INSTRUMENT/DETECTOR/yaw")
    rotation_2 = -extract_fromH5("ENTRY/INSTRUMENT/DETECTOR/pitch")
    rotation_3 = -extract_fromH5("ENTRY/INSTRUMENT/DETECTOR/roll")
    dict_parameters["detector rotation"] = [[rotation_1, rotation_2, rotation_3]]
    
    # Name of the sample
    sample_name = file["ENTRY/SAMPLE"].attrs["name"]
    dict_parameters["sample name"] = sample_name
    return dict_parameters

# %% [markdown]
# # Extraction and plotting of the data in q-space
#
# To extract the parameters necessary to compute the data in q-space, you have to do the following process.
#
# You can adjust the methods used according do the experiment type

# %%
# We extract the parameters thanks to the function we defined
parameters = extract_parameters(file_path)
parameters["geometry"]='Transmission'
print(parameters)
SMI_waxs = SMI_beamline.SMI_geometry(geometry=parameters["geometry"],
                                     sdd=parameters["distance"],
                                     wav=parameters["wavelength"],
                                     alphai=parameters["alpha"],
                                     center=parameters["beam center"],
                                     bs_pos=parameters["beam stop"],
                                     detector=parameters["detector"],
                                     det_angles=parameters["detector rotation"])

# We open and process the data thanks to the SMI_analysis package
# First we process the data to have it in the q-space
SMI_waxs.open_data_db(parameters["data"])
SMI_waxs.masks = np.logical_not(np.ones(np.shape(SMI_waxs.imgs)))
SMI_waxs.calculate_integrator_trans(parameters["detector rotation"])
SMI_waxs.stitching_data()

fig, ax = plt.subplots(layout="constrained")
ax.set_title('2D Data in q-space')
cplot = ax.imshow(SMI_waxs.img_st,
           extent=[SMI_waxs.qp[0], SMI_waxs.qp[-1], SMI_waxs.qz[0], SMI_waxs.qz[-1]],
           vmin=0,
           vmax=np.percentile(SMI_waxs.img_st[~np.isnan(SMI_waxs.img_st)], 99),
           cmap="magma")
ax.set_xlabel('$q_{x} (A^{-1}$)')
ax.set_ylabel('$q_{y} (A^{-1}$)')
cbar = plt.colorbar(cplot, ax=ax)
cbar.set_label("Intensity")
plt.show()
# Out:
# {'beam stop': [[0, 0]], 'data': [array([[-1.0000000e+00, -1.0000000e+00, -1.0000000e+00, ...,
#         -1.0000000e+00, -1.0000000e+00, -1.0000000e+00],
#        [-1.0000000e+00,  0.0000000e+00,  1.4936407e+00, ...,
#         -1.0240000e+03, -1.0240000e+03, -1.0000000e+00],
#        [-1.0000000e+00,  2.9532735e+00,  8.1476760e-01, ...,
#         -1.0240000e+03, -1.0240000e+03, -1.0000000e+00],
#        ...,
#        [-1.0000000e+00, -1.0240000e+03, -1.0240000e+03, ...,
#          8.2846570e-01,  0.0000000e+00,  0.0000000e+00],
#        [-1.0000000e+00, -1.0240000e+03, -1.0240000e+03, ...,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#        [-1.0000000e+00, -1.0000000e+00, -1.0000000e+00, ...,
#          0.0000000e+00,  6.1670285e-01,  1.5973070e+00]], dtype=float32)], 'beam center': [602.1808, 918.1508], 'distance': 0.499999, 'wavelength': 1.541891e-10, 'alpha': 0.008726646259971648, 'detector rotation': [[-0.0, -0.0, 0]], 'sample name': 'sample_sow7-143', 'geometry': 'Transmission'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 11
#       3 parameters["geometry"]='Transmission'
#       4 print(parameters)
#       5 SMI_waxs = SMI_beamline.SMI_geometry(geometry=parameters["geometry"],
#       6                                      sdd=parameters["distance"],
#       7                                      wav=parameters["wavelength"],
#       8                                      alphai=parameters["alpha"],
#       9                                      center=parameters["beam center"],
#      10                                      bs_pos=parameters["beam stop"],
# ---> 11                                      detector=parameters["detector"],
#      12                                      det_angles=parameters["detector rotation"])
#      14 # We open and process the data thanks to the SMI_analysis package
#      15 # First we process the data to have it in the q-space
#      16 SMI_waxs.open_data_db(parameters["data"])
#
# KeyError: 'detector'

# %% [markdown]
# # Integration following an horizontal or vertical section
#
# To integrate over an horizontal or vertical section you have to do he following.
#
# You can change the parameters qx_min, qx_max, qy_min, qy_max to change the interval of integration

# %%
# Horizontal integration
qy_min = 0.02
qy_max = 0.04

SMI_waxs.horizontal_integration(q_per_range=[qy_min, qy_max])
q_horizontal, I_horizontal = SMI_waxs.q_hor, SMI_waxs.I_hor

# Vertical integration
qx_min = -0.05
qx_max = 0.05

SMI_waxs.vertical_integration(q_par_range=[qx_min, qx_max])
q_vertical, I_vertical = SMI_waxs.q_ver, SMI_waxs.I_ver

fig, ax = plt.subplots(2, 1, layout="constrained")
ax[0].plot(q_horizontal, I_horizontal, color="orange")
ax[0].set_title(f"Integration over a horizontal section of thickness [{qy_min}, {qy_max}]")
ax[0].set_xlabel("$q_{x} (A^{-1}$")
ax[0].set_ylabel("Integration")
ax[0].set_yscale("log")

ax[1].plot(q_vertical, I_vertical, color="darkorchid")
ax[1].set_title(f"Integration over a vertical section of thickness [{qx_min}, {qx_max}]")
ax[1].set_xlabel("$q_{y} (A^{-1}$")
ax[1].set_ylabel("Integration")
ax[1].set_yscale("log")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Radial averaging of the data
# To get the radial average of the intensity in q-space, you can do the following.
#
# You can change the radial and azimuthal range

# %%
# You can modify the following
radial_min = 0.000
radial_max = 0.03

azimuthal_min = -180
azimuthal_max = 180
number_point = 2000

# We then compute the radial average
SMI_waxs.radial_averaging(radial_range=[radial_min, radial_max],
                          azimuth_range=[azimuthal_min, azimuthal_max], 
                          npt=number_point)
q, I = SMI_waxs.q_rad, SMI_waxs.I_rad

fig, ax = plt.subplots(figsize=(9, 5), layout="constrained")
ax.plot(q, I, color="darkred")
ax.set_title(f"Radial average in the azimuthal range {azimuthal_min, azimuthal_max}")
ax.set_xlabel("radius")
ax.set_ylabel("Intensity")
ax.set_yscale("log")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">
# C:\Users\AT280565\AppData\Local\Temp\ipykernel_15608\1207958688.py:20: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.set_yscale("log")

# %% [markdown]
# # Batch processing of several files
#
# To process multiple files in one batch, please provide the absolute path of the directory.
#
# If you would like to save your reduced data, please set the variable do_save to True and provide the absolute path directory that will store the reduced data

# %%
load_directory = "C:\\Users\\AT280565\\PycharmProjects\\EdfToHdf5\\data\\to_process\\"

do_save = True
save_directory = "C:\\Users\\AT280565\\PycharmProjects\\EdfToHdf5\\data\\Processed_files\\"

fig, ax = plt.subplots(figsize=(9, 5), layout="constrained")
for file in os.listdir(load_directory):
    print(load_directory+file)
    parameters = extract_parameters(load_directory+file)
    SMI_waxs = SMI_beamline.SMI_geometry(geometry=parameters["geometry"],
                                     sdd=parameters["distance"],
                                     wav=parameters["wavelength"],
                                     alphai=parameters["alpha"],
                                     center=parameters["beam center"],
                                     bs_pos=parameters["beam stop"],
                                     detector=parameters["detector"],
                                     det_angles=parameters["detector rotation"])
    
    SMI_waxs.open_data_db(parameters["data"])
    SMI_waxs.masks = np.logical_not(np.ones(np.shape(SMI_waxs.imgs)))
    SMI_waxs.calculate_integrator_trans(parameters["detector rotation"])
    SMI_waxs.stitching_data()
    
    SMI_waxs.radial_averaging(radial_range=[1, 3.5],azimuth_range=[-180, 180], npt=2000)
    
    ax.plot(SMI_waxs.q_rad, SMI_waxs.I_rad, label=file)

ax.set_yscale("log")
fig.legend()
if do_save:
    plt.savefig(save_directory+"batch_process.png")
else:
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 7
#       4 save_directory = "C:\\Users\\AT280565\\PycharmProjects\\EdfToHdf5\\data\\Processed_files\\"
#       6 fig, ax = plt.subplots(figsize=(9, 5), layout="constrained")
# ----> 7 for file in os.listdir(load_directory):
#       8     print(load_directory+file)
#       9     parameters = extract_parameters(load_directory+file)
#
# FileNotFoundError: [WinError 3] Le chemin d’accès spécifié est introuvable: 'C:\\Users\\AT280565\\PycharmProjects\\EdfToHdf5\\data\\to_process\\'
